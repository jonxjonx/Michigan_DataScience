# %% [markdown]
# Q1

# %%
import pandas as pd

student_df = pd.DataFrame([{'Name': 'James', 'School': 'Business'},
                         {'Name': 'Mike', 'School': 'Law'},
                         {'Name': 'Sally', 'School': 'Engineering'}])

staff_df = pd.DataFrame([{'Name': 'Kelly', 'Role': 'Director of HR'},
                         {'Name': 'Sally', 'Role': 'Course liasion'},
                         {'Name': 'James', 'Role': 'Grader'}])

# %%
student_df = student_df.set_index('Name')
staff_df = staff_df.set_index('Name')

# %%
pd.merge(student_df, staff_df, how='left', left_index=True, right_index=True)  # left and right index true hence merge will join based on indices
# Out:
#             School            Role
# Name
# James     Business          Grader
# Mike           Law             NaN
# Sally  Engineering  Course liasion

# %% [markdown]
# Q2

# %% [markdown]
# * axis=0 means row, axis=1 means column
#
# * df['AVG'] = df[frames].apply(lambda z: np.mean(z), axis=x)   - apply is to add
#
# * result_df = df.drop(frames,axis=y)       - drop is to remove

# %% [markdown]
# Q3

# %% [markdown]
# * ordered = True means the categories have a order
# * my_categories = pd.CategoricalDtype(categories=['D', 'D+', 'C-', 'C', 'C+', 'B-', 'B', 'B+', 'A-', 'A', 'A+'], ordered=True)

# %% [markdown]
# Q4

# %% [markdown]
# * margins = True will add a ALL column showing the aggregate value
# * df.pivot_table(values='score', index='country', columns='Rank_Level', aggfunc=[np.median], margins=True)

# %% [markdown]
# Q5

# %% [markdown]
# * adding .offsets.MonthEnd() will move the date to the last day of the month (which is 11/30/2019)
# * .weekday() will return the day of the week as an integer (Monday is 0, Sunday is 6)
# * 11/30/2019 is Sat which is 5

# %%
(pd.Timestamp('11/29/2019') + pd.offsets.MonthEnd()).weekday()
# Out:
# 5

# %% [markdown]
# Q6

# %% [markdown]
# * filling_mean = lambda g: g.fillna(g.mean())
# * df.groupby(group_key).apply(filling_mean)

# %% [markdown]
# Q7

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * result_df = pd.merge(staff_df, student_df, how='right', on=['First Name', 'Last Name'])
# * staff first hence how is right

# %% [markdown]
# Q8

# %% [markdown]
# * df.groupby('review_scores_value').agg({'name': len, 'reviews_per_month': (np.nanmean, np.nanstd)})
# * calculates mean and std ignoring NaN values

# %% [markdown]
# Q9

# %% [markdown]
# * adds 5 periods which is in months

# %%
pd.Period('01/12/2019', 'M') + 5
# Out:
# Period('2019-06', 'M')

# %% [markdown]
# Q10

# %% [markdown]
# * df.groupby('vegetable')
