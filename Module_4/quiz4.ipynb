# %% [markdown]
# Q1

# %%
import numpy as np
a = np.arange(8)
b = a[4:6]
b[:] = 40

# %% [markdown]
# slice is a view of the original array and not a copy, hence the changes in b will directly affect a

# %% [markdown]
# Q2

# %%
import re
s = 'ABCAC'

re.match('A', s)
# Out:
# <re.Match object; span=(0, 1), match='A'>

# %% [markdown]
# match checks if 'A' is at beginning of s

# %% [markdown]
# Q3

# %%
def result():
    s = 'ACAABAACAAABACDBADDDFSDDDFFSSSASDAFAAACBAAAFASD'

    result = []
    # compete the pattern below
    pattern = r"[A-Z](?=AAA)"
    for item in re.finditer(pattern, s):
      # identify the group number below.
      result.append(item.group())
      
    return result

result()
# Out:
# ['C', 'F', 'B']

# %% [markdown]
# * match any uppercase letter from A to Z
# * checks if letter is followed by AAA

# %% [markdown]
# Q4

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * df.index[0] will give first index which is d
# * df[0], df.iloc[0], df['d] wil give 4

# %% [markdown]
# Q5

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * .add() add values together only if label is present in both. If present in one, it will be NaN
# * .add(s2, fill_value=0) fills missing values (NaN) with 0

# %% [markdown]
# Q6

# %% [markdown]
# * Every time we call df.set_index(), the old index will be discarded.
# * Every time we call df.reset_index(), the old index will be set as a new column.

# %% [markdown]
# Q7

# %% [markdown]
# * slicing in pandas is different from normal way of integer based positions
# * it is inclusive of both start and end

# %%
import pandas as pd
S = pd.Series(np.arange(5), index=['a', 'b', 'c', 'd', 'e'])
S['b':'e']
# Out:
# b    1
# c    2
# d    3
# e    4
# dtype: int32

# %% [markdown]
# Q8

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# f = lambda x: x.max() + x.min()
#
# df_new = df.apply(f)
#
# df_new[1] = 88, max and min of column b

# %% [markdown]
# Q9

# %% [markdown]
# ![image.png](attachment:image.png)
#
# new_df.unstack().unstack()

# %% [markdown]
# Q10

# %% [markdown]
# ![image.png](attachment:image.png)
#
# df.groupby('Item').sum().iloc[0]['Quantity sold'] will group item_1 and sum the quality sold
